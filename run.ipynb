# %%
# !git clone https://github.com/7i10/WMEP-ETA.git

# %%
# %cd '/content/WMEP-ETA'

# %%
# !python3 ETA_WMEP_CIFAR10.py

# %%
# !python3 ETA_WMEP_CIFAR100.py

# %%
# !python3 test_cifar10.py --best_model_path 'CIFAR10/test_model/ETA_WMEP_best_model.pth' --last_model_path 'CIFAR10/test_model/ETA_WMEP_last_model.pth' --out_best_file 'test_best_log.txt' --out_last_file 'test_last_log.txt'

# %%
# !python3 test_cifar100.py --best_model_path 'CIFAR100/test_model/ETA_WMEP_best_model.pth' --last_model_path 'CIFAR100/test_model/ETA_WMEP_last_model.pth' --out_best_file 'test_best_log.txt' --out_last_file 'test_last_log.txt'
